# %%
import pandas as np
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/'Colab Notebooks'/RL/pong_test/DDQN/

# %ls
# %pip install -U gym>=0.21.0
# %pip install -U gym[atari,accept-rom-license]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/RL/pong_test/DDQN
# '=0.21.0'       network.py     results/    test_pong_DDQN.ipynb   video/
#  main_DDQN.py   __pycache__/   test_pong  'test result'/          wrappers.py
# ...

# %%
# !python /content/drive/MyDrive/Colab\ Notebooks/RL/pong_test/DDQN/main_DDQN.py
# Out:
# /usr/local/lib/python3.7/dist-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):
# ...
# Now PlayingPongNoFrameskip-v4
# ...
# Starting new training...
# Step = 0
# Reward = 0
# Epsilon = 1.0
# Starting new training...
# A.L.E: Arcade Learning Environment (version +978d2ce)
# [Powered by Stella]
# epsode 1: reward: -20.0 || q_value: 0.007421 || Passed steps: 864  || Total steps:864 || Epsilon: 0.914563
# epsode 2: reward: -18.0 || q_value: -0.003207 || Passed steps: 1348  || Total steps:2212 || Epsilon: 0.781111
# epsode 3: reward: -21.0 || q_value: -0.015580 || Passed steps: 844  || Total steps:3056 || Epsilon: 0.697555
# epsode 4: reward: -21.0 || q_value: -0.082980 || Passed steps: 845  || Total steps:3901 || Epsilon: 0.6139
# epsode 5: reward: -21.0 || q_value: -0.062590 || Passed steps: 816  || Total steps:4717 || Epsilon: 0.533116
# ...
